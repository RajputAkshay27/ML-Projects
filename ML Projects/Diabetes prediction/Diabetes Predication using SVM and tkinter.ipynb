# %%
import tkinter as tk
from tkinter import ttk
import numpy as np
from tkinter import messagebox

# %%
import pandas as pd

df = pd.read_csv('diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
X = df.drop('Outcome', axis = 1)
y = df[['Outcome']]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
print(X_train.shape)
print(X_test.shape)
# Out:
# (514, 8)
# (254, 8)

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
from sklearn import svm
from sklearn import metrics

# %%
clf = svm.SVC(kernel='linear') # Linear Kernel
y_train=np.reshape(y_train,(514,))
print(y_train.shape)
y_train2=np.ravel(y_train)
print(y_train2.shape)
# Out:
# (514, 1)
# (514,)

# %%
clf.fit(X_train,y_train2)
# Out:
# SVC(kernel='linear')

# %%
y_pred = clf.predict(X_test)

# %%
from  sklearn.metrics import accuracy_score
ac = accuracy_score(y_test, y_pred)
print(ac)
# Out:
# 0.7559055118110236

# %%
def Output():
    print(DB["Pregnancies"])
    DB["Pregnancies"] = pd.to_numeric(DB["Pregnancies"])
    DB["Glucose"] = pd.to_numeric(DB["Glucose"])
    DB["BloodPressure"] = pd.to_numeric(DB["BloodPressure"])
    DB["SkinThickness"] = pd.to_numeric(DB["SkinThickness"])
    DB["Insulin"] = pd.to_numeric(DB["Insulin"])
    DB["BMI"] = pd.to_numeric(DB["BMI"])
    DB["DiabetesPedigreeFunction"] = pd.to_numeric(DB["DiabetesPedigreeFunction"])
    DB["Age"] = pd.to_numeric(DB["Age"])
    print(DB)

# %%
import pandas as pd
DF = pd.DataFrame()

def action():
    global DB
    import pandas as pd
    DF = pd.DataFrame(columns=['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age'])
    PREGNANCIES=Pregnancies.get()
    DF.loc[0,'Pregnancies']=PREGNANCIES
    GLUCOSE=Glucose.get()
    DF.loc[0,'Glucose']=GLUCOSE
    BLOODPRESSURE=BloodPressure.get()
    DF.loc[0,'BloodPressure']=BLOODPRESSURE
    SKINTHIKNESS=SkinThickness.get()
    DF.loc[0,'SkinThickness']=SKINTHIKNESS
    INSULIN=Insulin.get()
    DF.loc[0,'Insulin']=INSULIN
    BMI=Bmi.get()
    DF.loc[0,'BMI']=BMI
    DIABETESPEDIGREEFUNCTION=DiabetesPedigreeFunction.get()
    DF.loc[0,'DiabetesPedigreeFunction']=DIABETESPEDIGREEFUNCTION
    AGE=Age.get()
    DF.loc[0,'Age']=AGE
    print(DF.shape)
    print(DF)
    print(type(DF))
    print(type(DF["Pregnancies"][0]))
    DB=DF

# %%
import pickle    
model=clf
filename="dia_model.pkl"
pickle.dump(model,open(filename, 'wb'))

# %%
def make_predict():
    import pickle
    global result
    model = pickle.load(open('dia_model.pkl', 'rb'))
    output=model.predict(DB)
    if output==1:
        result='Diabetic'
    elif output==0:
        result='Non-Diabetic'
    print(result)    

def get_res():
    messagebox.showinfo(title='Diagnosis Result', message=result)

# %%
window = tk.Tk()
window.title("Diabetes Prediction")
Pregnancies = tk.StringVar()
Glucose = tk.StringVar()
BloodPressure = tk.StringVar()
SkinThickness = tk.StringVar()
Insulin = tk.StringVar()
Bmi = tk.StringVar()
DiabetesPedigreeFunction = tk.StringVar()
Age = tk.StringVar()

label1 = tk.Label(window,text = "Pregnancies:").grid(row = 0, column = 0,pady = 4)
tk.Entry(window,width = 36,textvariable = Pregnancies).grid(row = 0, column = 1,pady = 4)

label2 = tk.Label(window,text = "Glucose:").grid(row = 1, column = 0,pady = 4)
tk.Entry(window,width = 36,textvariable = Glucose).grid(row = 1, column = 1,pady = 4)

label3 = tk.Label(window,text = "BloodPressure:").grid(row = 2, column = 0,pady = 4)
tk.Entry(window,width = 36,textvariable = BloodPressure).grid(row = 2, column = 1,pady = 4)

label4 = tk.Label(window,text = "SkinThickness:").grid(row = 3, column = 0,pady = 4)
tk.Entry(window,width = 36,textvariable = SkinThickness).grid(row = 3, column = 1,pady = 4)

label5 = tk.Label(window,text = "Insulin:").grid(row = 4, column = 0,pady = 4)
tk.Entry(window,width = 36,textvariable = Insulin).grid(row = 4, column = 1,pady = 4)

label6 = tk.Label(window,text = "BMI:").grid(row = 5, column = 0,pady = 4)
tk.Entry(window,width = 36,textvariable = Bmi).grid(row = 5, column = 1,pady = 4)

label7 = tk.Label(window,text = "DiabetesPedigreeFunction:").grid(row = 6, column = 0,pady = 4)
tk.Entry(window,width = 36,textvariable = DiabetesPedigreeFunction).grid(row = 6, column = 1,pady = 4)

label8 = tk.Label(window,text = "Age:").grid(row = 7, column = 0,pady = 4)
tk.Entry(window,width = 36,textvariable = Age).grid(row = 7, column = 1,pady = 4)

tk.Button(window,text="Submit",command=action).grid(row=7,column=6)

tk.Button(window,text="Transform",command=Output).grid(row=7,column=10)

Predict_button=tk.Button(window,text="Predict",command=make_predict)
Predict_button.grid(row=20,column=0)
tk.Button(window,text='Show',command=get_res).grid(row=21,column=0)

tk.mainloop()
# Out:
# (1, 8)
#   Pregnancies Glucose BloodPressure SkinThickness Insulin   BMI  \
# 0          20     192           120            35      31  33.6
#
#   DiabetesPedigreeFunction Age
# 0                    0.315  61
# <class 'pandas.core.frame.DataFrame'>
# <class 'str'>
# 0    20
# Name: Pregnancies, dtype: object
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0           20      192            120             35       31  33.6
#
#    DiabetesPedigreeFunction  Age
# 0                     0.315   61
# Diabetic
# (1, 8)
#   Pregnancies Glucose BloodPressure SkinThickness Insulin   BMI  \
# 0           3      80           120            35       3  33.6
#
#   DiabetesPedigreeFunction Age
# 0                    0.315  61
# <class 'pandas.core.frame.DataFrame'>
# <class 'str'>
# 0    3
# Name: Pregnancies, dtype: object
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            3       80            120             35        3  33.6
#
# ...
